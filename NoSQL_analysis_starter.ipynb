# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Notebook Set Up

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our database
db.list_collection_names()
# Out:
# ['establishments']

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %%
# Use count_documents to display the number of documents contained in the result.
establishments.count_documents({})
# Out:
# 38786

# %%
# Display the first document in the results using pprint.
pprint(establishments.find_one({}))
# Out:
# {'AddressLine1': 'East Cliff Pavilion',
#  'AddressLine2': 'Wear Bay Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'The Pavilion',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4591.765489457773,
#  'FHRSID': 1043695,
#  'LocalAuthorityBusinessID': 'PI/000073616',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT19 6BL',
#  'RatingDate': '2018-04-04T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64fce48241b306a39f13b919'),
#  'geocode': {'latitude': 51.083812, 'longitude': 1.195625},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1043695',
# ...

# %%
# Convert the result to a Pandas DataFrame
import pandas as pd

# %%
# print the number of rows in the DataFrame, and display the first 10 rows.
df = pd.DataFrame(list(establishments.find({}) ))
print('dataframe length:', len(df))
df.head(10)
# Out:
# dataframe length: 38786
#                         _id     FHRSID  ChangesByServerID  \
# 0  64fce48241b306a39f13b919  1043695.0                0.0
# 1  64fce48241b306a39f13b91a   647177.0                0.0
# 2  64fce48241b306a39f13b91d   289352.0                0.0
# 3  64fce48241b306a39f13b91e   987206.0                0.0
# 4  64fce48241b306a39f13b91f   289560.0                0.0
# 5  64fce48241b306a39f13b920   289353.0                0.0
# 6  64fce48241b306a39f13b921   344689.0                0.0
# 7  64fce48241b306a39f13b922   894592.0                0.0
# 8  64fce48241b306a39f13b923  1043701.0                0.0
# 9  64fce48241b306a39f13b924   805702.0                0.0
#
#   LocalAuthorityBusinessID                         BusinessName  \
# 0             PI/000073616                         The Pavilion
# 1             PI/000041489                  Wear Bay Bowls Club
# 2             PI/000002460                             The Ship
# ...

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
# Find the establishments with a hygiene score of 20
query = {'scores.Hygiene' : {'$eq' : 20}}
result = establishments.find(query)

# Use count_documents to display the number of documents in the result
print(establishments.count_documents(query))

# Display the first document in the results using pprint
result[0]
# Out:
# 41
# {'_id': ObjectId('64fce48241b306a39f13d450'),
#  'FHRSID': 110681,
#  'ChangesByServerID': 0,
#  'LocalAuthorityBusinessID': '4029',
#  'BusinessName': 'The Chase Rest Home',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'AddressLine1': '5-6 Southfields Road',
#  'AddressLine2': 'Eastbourne',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'PostCode': 'BN21 1BU',
#  'Phone': '',
#  'RatingValue': 0,
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingDate': '2021-09-23T00:00:00',
#  'LocalAuthorityCode': '102',
#  'LocalAuthorityName': 'Eastbourne',
#  'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#  'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#  'scores': {'Hygiene': 20, 'Structural': 20, 'ConfidenceInManagement': 20},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': 0.27694, 'latitude': 50.769705},
#  'RightToReply': '',
#  'Distance': 4613.888288172291,
#  'NewRatingPending': False,
# ...

# %%
# Convert the result to a Pandas DataFrame
query = {'scores.Hygiene' : {'$eq' : 20}}
result = establishments.find(query)
df2 = pd.DataFrame(list(result))

# Display the number of rows in the DataFrame
print('number of rows:', len(df2))
# Display the first 10 rows of the DataFrame
df2.head(10)
# Out:
# number of rows: 41
#                         _id   FHRSID  ChangesByServerID  \
# 0  64fce48241b306a39f13d450   110681                  0
# 1  64fce48241b306a39f13d7d4   612039                  0
# 2  64fce48241b306a39f13dae0   730933                  0
# 3  64fce48241b306a39f13dccd   172735                  0
# 4  64fce48241b306a39f13dcdb   172953                  0
# 5  64fce48241b306a39f13e67c   512854                  0
# 6  64fce48241b306a39f13e89b  1537089                  0
# 7  64fce48341b306a39f13fdc2   155648                  0
# 8  64fce48341b306a39f14020a  1012883                  0
# 9  64fce48341b306a39f140a1c   644109                  0
#
#   LocalAuthorityBusinessID               BusinessName  \
# 0                     4029        The Chase Rest Home
# 1                1970/FOOD                 Brenalwood
# 2                1698/FOOD              Melrose Hotel
# 3             PI/000023858              Seaford Pizza
# ...

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
# Find the establishments with London as the Local Authority and has a RatingValue greater than or equal to 4.
result = establishments.find( {'AddressLine2' : {'$eq': 'London'},
                               'RatingValue' : {'$gte' : 4} })

# Use count_documents to display the number of documents in the result
print(establishments.count_documents( {'AddressLine2' : {'$eq': 'London'},
                               'RatingValue' : {'$gte' : 4} }))
# Display the first document in the results using pprint
result[0]
# Out:
# 99
# {'_id': ObjectId('64fce48341b306a39f1411eb'),
#  'FHRSID': 294900,
#  'ChangesByServerID': 0,
#  'LocalAuthorityBusinessID': 'PI/000019066',
#  'BusinessName': 'Mv Valulla',
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'AddressLine1': 'Reeds River Cruises LtdKings ReachRiver ThamesSouthwark',
#  'AddressLine2': 'London',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'PostCode': 'RM15 5QY',
#  'Phone': '',
#  'RatingValue': 5,
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingDate': '2016-08-23T00:00:00',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': 0.287555, 'latitude': 51.504071},
#  'RightToReply': '',
# ...

# %%
# Convert the result to a Pandas DataFrame
result = establishments.find( {'AddressLine2' : {'$eq': 'London'},
                               'RatingValue' : {'$gte' : 4} })
df3 = pd.DataFrame(list(result))
# Display the number of rows in the DataFrame
print('number of rows:', len(df3))
# Display the first 10 rows of the DataFrame
df3.head(10)
# Out:
# number of rows: 99
#                         _id   FHRSID  ChangesByServerID  \
# 0  64fce48341b306a39f1411eb   294900                  0
# 1  64fce48341b306a39f14277b  1408389                  0
# 2  64fce48341b306a39f14278f  1438466                  0
# 3  64fce48341b306a39f142790  1156030                  0
# 4  64fce48341b306a39f142817   776404                  0
# 5  64fce48341b306a39f14281a   930899                  0
# 6  64fce48341b306a39f142838   875250                  0
# 7  64fce48341b306a39f142844  1064870                  0
# 8  64fce48341b306a39f1428ed  1223157                  0
# 9  64fce48341b306a39f1428f0   996676                  0
#
#   LocalAuthorityBusinessID                                       BusinessName  \
# 0             PI/000019066                                         Mv Valulla
# 1              21/00294/CP                                           Foodyz21
# 2              22/00008/CP                     Finest Chicken Peri Peri Grill
# ...

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of 5, sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
result = establishments.find( {'RatingValue' : {'$eq': 5},
                               'geocode.latitude' : {'$gte' : .01} })

geocode.latitude

# %%
db.collection.find({ field: { $gte: value - 0.01, $lte: value + 0.01 } })

# %%
lat = establishments.find({'BusinessName' : 'Penang Flavours'}, {'_id':0, 'geocode':1})
#lat = establishments.find({'BusinessName' : 'Penang Flavours'})
print(lat[0])
# Out:
# {'geocode': {'longitude': None, 'latitude': None}}

# %%
# Search within 0.01 degree on either side of the latitude and longitude.

# Rating value must equal 5

# Sort by hygiene score

degree_search = 0.01
latitude = 
longitude = 

query = 
sort =  

# Print the results

# %%
# Convert result to Pandas DataFrame

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
# Create a pipeline that: 
# 1. Matches establishments with a hygiene score of 0
matches ={'$match': {'scores.Hygiene' : {'$eq' : 5} }}

# 2. Groups the matches by Local Authority
group ={'$group':{'_id': "$LocalAuthorityName", 
                     'count': { '$sum': 1 }} }
 
# 3. Sorts the matches from highest to lowest
sort = {'$sort':{'count': -1}}

pipeline = [matches, group, sort]
results = list(establishments.aggregate(pipeline))
# Print the number of documents in the result
print(len(results))
# Print the first 10 results
pprint(results[0:10])
# Out:
# 60
# [{'_id': 'Redbridge', 'count': 964},
#  {'_id': 'Wealden', 'count': 839},
#  {'_id': 'Canterbury City', 'count': 750},
#  {'_id': 'Rother', 'count': 664},
#  {'_id': 'Newham', 'count': 662},
#  {'_id': 'Havering', 'count': 621},
#  {'_id': 'Colchester', 'count': 566},
#  {'_id': 'Southend-On-Sea', 'count': 542},
#  {'_id': 'Epping Forest', 'count': 539},
#  {'_id': 'Bromley', 'count': 488}]

# %%
# Convert the result to a Pandas DataFrame
result_df = pd.DataFrame(results)
# Display the number of rows in the DataFrame
print("Rows in DataFrame: ", len(result_df))
# Display the first 10 rows of the DataFrame
result_df.head(10)
# Out:
# Rows in DataFrame:  60
#                      _id  count
# 0           West Suffolk      1
# 1                Wealden    839
# 2         Waltham Forest    187
# 3             Uttlesford    146
# 4        Tunbridge Wells    169
# 5          Tower Hamlets      3
# 6  Tonbridge and Malling    265
# 7               Thurrock    254
# 8                 Thanet     19
# 9               Tendring    243
